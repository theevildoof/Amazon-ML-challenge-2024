# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
loss_df = pd.read_csv('loss (2).csv')
loss_df['mean_loss'] = loss_df['loss'].rolling(window= 100).mean()

# %%
sns.lineplot(data= loss_df, x='index', y='mean_loss')
plt.show()
